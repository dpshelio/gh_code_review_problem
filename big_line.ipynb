# %% [markdown]
# # Problem with long lines in GH

# %%
def define_a_function(number, factor=0.05):
    return number * factor

# %% [markdown]
# But now things get strange!

# %%
a_variable =  extra_space_function()
a_value = define_a_function(3, 0.01)
# some fancy triangulation L plot
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
for mesh, ax in zip((mesh_a, mesh_b), axes):
    triangulation = get_matplotlib_triangulation_from_mesh(mesh)
    ax.triplot(triangulation)
    ax.set_aspect(1)
fig.tight_layout()
